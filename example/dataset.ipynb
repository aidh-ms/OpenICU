# %%
from pathlib import Path

from open_icu.config.dataset.source.regestry import DatasetConfigRegistry

registry = DatasetConfigRegistry.from_path(Path.cwd().parent / "config" / "dataset")
registry.all()
# Out:
# [SourceDatasetConfig(name='eicu', version='2.0', tables=[TableConfig(name='patient', path='patient.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='patienthealthsystemstayid', type='int64'), ConstantFieldConfig(name='hadm_id', type='int64', constant=-1), FieldConfig(name='patientunitstayid', type='int64'), FieldConfig(name='unittype', type='string'), ConstantFieldConfig(name='in_code', type='string', constant='ICU_ADMISSION'), ConstantFieldConfig(name='out_code', type='string', constant='ICU_DISCHARGE')], callbacks=[], join=[], events=[EventConfig(name='icu_admission', fields=MEDSEventFieldConfig(subject_id='patienthealthsystemstayid', time='admission_timestamp', code=['in_code', 'unittype'], numeric_value=None, text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'patientunitstayid'}), callbacks=[]), EventConfig(name='icu_discharge', fields=MEDSEventFieldConfig(subject_id='patienthealthsystemstayid', time='discharge_timestamp', code=['out_code', 'unittype'], numeric_value=None, text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'patientunitstayid'}), callbacks=[])]), TableConfig(name='vitalPeriodic', path='vitalPeriodic.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='patientunitstayid', type='int64'), FieldConfig(name='heartrate', type='float32'), ConstantFieldConfig(name='heartrate_code', type='string', constant='HEART_RATE//BPM')], callbacks=[], join=[JsonTableConfig(name='patient', path='patient.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='patienthealthsystemstayid', type='int64'), ConstantFieldConfig(name='hadm_id', type='int64', constant=-1), FieldConfig(name='patientunitstayid', type='int64')], callbacks=[], both_on=['patientunitstayid'], left_on=[], right_on=[], how='left')], events=[EventConfig(name='heartrate', fields=MEDSEventFieldConfig(subject_id='patienthealthsystemstayid', time='event_timestamp', code=['heartrate_code'], numeric_value='heartrate', text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'patientunitstayid'}), callbacks=[])]), TableConfig(name='infusionDrug', path='infusionDrug.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='patientunitstayid', type='int64'), FieldConfig(name='drugamount', type='float32'), FieldConfig(name='drugname', type='string')], callbacks=[], join=[JsonTableConfig(name='patient', path='patient.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='patienthealthsystemstayid', type='int64'), ConstantFieldConfig(name='hadm_id', type='int64', constant=-1), FieldConfig(name='patientunitstayid', type='int64')], callbacks=[], both_on=['patientunitstayid'], left_on=[], right_on=[], how='left')], events=[EventConfig(name='drugamount', fields=MEDSEventFieldConfig(subject_id='patienthealthsystemstayid', time='event_timestamp', code=['drugname'], numeric_value='drugamount', text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'patientunitstayid'}), callbacks=[])])]),
#  SourceDatasetConfig(name='mimic-iv', version='3.1', tables=[TableConfig(name='icustays', path='icu/icustays.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='subject_id', type='int64'), FieldConfig(name='hadm_id', type='int64'), FieldConfig(name='stay_id', type='int64'), FieldConfig(name='intime', type='datetime'), FieldConfig(name='outtime', type='datetime'), FieldConfig(name='first_careunit', type='string'), FieldConfig(name='last_careunit', type='string'), FieldConfig(name='los', type='float32'), ConstantFieldConfig(name='in_code', type='string', constant='ICU_ADMISSION'), ConstantFieldConfig(name='out_code', type='string', constant='ICU_DISCHARGE'), ConstantFieldConfig(name='los_code', type='string', constant='ICU_LENGTH_OF_STAY'), ConstantFieldConfig(name='los_unit', type='string', constant='d')], callbacks=[], join=[], events=[EventConfig(name='icu_admission', fields=MEDSEventFieldConfig(subject_id='subject_id', time='intime', code=['in_code', 'first_careunit'], numeric_value=None, text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'stay_id'}), callbacks=[]), EventConfig(name='icu_discharge', fields=MEDSEventFieldConfig(subject_id='subject_id', time='outtime', code=['out_code', 'last_careunit'], numeric_value=None, text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'stay_id'}), callbacks=[]), EventConfig(name='icu_length_of_stay', fields=MEDSEventFieldConfig(subject_id='subject_id', time='outtime', code=['los_code', 'los_unit'], numeric_value='los', text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'stay_id'}), callbacks=[])]), TableConfig(name='chartevents', path='icu/chartevents.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='subject_id', type='int64'), FieldConfig(name='hadm_id', type='int64'), FieldConfig(name='stay_id', type='int64'), FieldConfig(name='charttime', type='datetime'), FieldConfig(name='value', type='string'), FieldConfig(name='valuenum', type='float32'), FieldConfig(name='valueuom', type='string'), FieldConfig(name='itemid', type='int64')], callbacks=[], join=[JsonTableConfig(name='d_items', path='icu/d_items.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='itemid', type='int64'), FieldConfig(name='label', type='string')], callbacks=[], both_on=['itemid'], left_on=[], right_on=[], how='left')], events=[EventConfig(name='chartevent', fields=MEDSEventFieldConfig(subject_id='subject_id', time='charttime', code=['label', 'valueuom'], numeric_value='valuenum', text_value='value', extension={'hadm_id': 'hadm_id', 'stay_id': 'stay_id'}), callbacks=[])]), TableConfig(name='medications', path='icu/inputevents.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='subject_id', type='int64'), FieldConfig(name='hadm_id', type='int64'), FieldConfig(name='stay_id', type='int64'), FieldConfig(name='endtime', type='datetime'), FieldConfig(name='amount', type='float32'), FieldConfig(name='amountuom', type='string'), FieldConfig(name='starttime', type='datetime'), FieldConfig(name='rateuom', type='string'), FieldConfig(name='rate', type='float32'), FieldConfig(name='itemid', type='int64')], callbacks=[], join=[JsonTableConfig(name='d_items', path='icu/d_items.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='itemid', type='int64'), FieldConfig(name='label', type='string')], callbacks=[], both_on=['itemid'], left_on=[], right_on=[], how='left')], events=[EventConfig(name='dosage', fields=MEDSEventFieldConfig(subject_id='subject_id', time='endtime', code=['label', 'amountuom'], numeric_value='amount', text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'stay_id'}), callbacks=[]), EventConfig(name='rate', fields=MEDSEventFieldConfig(subject_id='subject_id', time='starttime', code=['label', 'rateuom'], numeric_value='rate', text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'stay_id'}), callbacks=[CallbackConfig(callback='drop_na', params={'columns': ['rate']}, call=<open_icu.transform.callbacks.filter.DropNa object at 0x ...
