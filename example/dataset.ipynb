# %%
from pathlib import Path

from open_icu.config.dataset.source.registry import DatasetConfigRegistry

registry = DatasetConfigRegistry.from_path(Path.cwd().parent / "config" / "dataset")
registry.values()
# Out:
# [SourceDatasetConfig(name='mimic-iv', version='3.1', tables=[TableConfig(name='chartevents', path='icu/chartevents.csv', type=<TableType.CSV: 'csv'>, fields=[ConstantFieldConfig(name='src_table_code', type='string', params={}, constant='icu/chartevents'), FieldConfig(name='hadm_id', type='int64', params={}), FieldConfig(name='stay_id', type='int64', params={}), ConstantFieldConfig(name='src_db_id', type='string', params={}, constant='mimic'), FieldConfig(name='subject_id', type='int64', params={}), FieldConfig(name='charttime', type='datetime', params={}), FieldConfig(name='itemid', type='int64', params={}), FieldConfig(name='value', type='string', params={}), FieldConfig(name='valuenum', type='float32', params={}), FieldConfig(name='valueuom', type='string', params={})], pre_callbacks=[], callbacks=[], post_callbacks=[], join=[JsonTableConfig(name='d_items', path='icu/d_items.csv', type=<TableType.CSV: 'csv'>, fields=[FieldConfig(name='itemid', type='int64', params={}), FieldConfig(name='label', type='string', params={})], pre_callbacks=[], callbacks=[], post_callbacks=[], both_on=['itemid'], left_on=[], right_on=[], how='left', dtypes={'itemid': Int64, 'label': String}, join_params={'on': ['itemid']})], events=[EventConfig(name='chartevent', fields=MEDSEventFieldConfig(subject_id='subject_id', time='charttime', code=['src_table_code', 'label', 'valueuom'], numeric_value='valuenum', text_value='value', extension={'hadm_id': 'hadm_id', 'stay_id': 'stay_id', 'src_db_id': 'src_db_id'}), callbacks=[])], dtypes={'src_table_code': String, 'hadm_id': Int64, 'stay_id': Int64, 'src_db_id': String, 'subject_id': Int64, 'charttime': String, 'itemid': Int64, 'value': String, 'valuenum': Float32, 'valueuom': String}), TableConfig(name='hcpcsevents', path='hosp/hcpcsevents.csv', type=<TableType.CSV: 'csv'>, fields=[ConstantFieldConfig(name='src_table_code', type='string', params={}, constant='hosp/hcpcsevents'), ConstantFieldConfig(name='hcspsevents_code', type='string', params={}, constant='HCPCS'), FieldConfig(name='hadm_id', type='int64', params={}), ConstantFieldConfig(name='stay_id', type='int64', params={}, constant=-1), ConstantFieldConfig(name='src_db_id', type='string', params={}, constant='mimic'), FieldConfig(name='subject_id', type='int64', params={}), FieldConfig(name='chartdate', type='datetime', params={}), FieldConfig(name='hcpcs_cd', type='string', params={}), FieldConfig(name='seq_num', type='int64', params={}), FieldConfig(name='short_description', type='string', params={})], pre_callbacks=[], callbacks=[], post_callbacks=[], join=[], events=[EventConfig(name='hpcsevent', fields=MEDSEventFieldConfig(subject_id='subject_id', time='chartdate', code=['src_table_code', 'hcspsevents_code', 'hcpcs_cd'], numeric_value='seq_num', text_value='short_description', extension={'hadm_id': 'hadm_id', 'stay_id': 'stay_id', 'src_db_id': 'src_db_id'}), callbacks=[])], dtypes={'src_table_code': String, 'hcspsevents_code': String, 'hadm_id': Int64, 'stay_id': Int64, 'src_db_id': String, 'subject_id': Int64, 'chartdate': String, 'hcpcs_cd': String, 'seq_num': Int64, 'short_description': String}), TableConfig(name='medications', path='icu/inputevents.csv', type=<TableType.CSV: 'csv'>, fields=[ConstantFieldConfig(name='src_table_code', type='string', params={}, constant='icu/inputevents'), FieldConfig(name='hadm_id', type='int64', params={}), FieldConfig(name='stay_id', type='int64', params={}), ConstantFieldConfig(name='src_db_id', type='string', params={}, constant='mimic'), FieldConfig(name='subject_id', type='int64', params={}), FieldConfig(name='endtime', type='datetime', params={}), FieldConfig(name='starttime', type='datetime', params={}), FieldConfig(name='amount', type='float32', params={}), FieldConfig(name='amountuom', type='string', params={}), FieldConfig(name='itemid', type='int64', params={}), FieldConfig(name='rate', type='float32', params={}), FieldConfig(name='rateuom', type='string', params={})], pre_callbacks=[], callbacks= ...
#  SourceDatasetConfig(name='eicu', version='2.0', tables=[TableConfig(name='infusionDrug', path='infusionDrug.csv', type=<TableType.CSV: 'csv'>, fields=[ConstantFieldConfig(name='src_table_code', type='string', params={}, constant='infusionDrug'), FieldConfig(name='patientunitstayid', type='int64', params={}), ConstantFieldConfig(name='src_db_id', type='string', params={}, constant='eicu'), FieldConfig(name='infusionoffset', type='int64', params={}), FieldConfig(name='drugamount', type='float32', params={}), FieldConfig(name='drugname', type='string', params={})], pre_callbacks=[], callbacks=[], post_callbacks=[CallbackConfig(callback='add_offset', params={'datetime': 'admission_timestamp', 'offset': 'infusionoffset', 'output': 'event_timestamp'}, call=<open_icu.transform.callbacks.time.AddOffset object at 0x763332aaa660>)], join=[JsonTableConfig(name='patient', path='patient.csv', type=<TableType.CSV: 'csv'>, fields=[ConstantFieldConfig(name='hadm_id', type='int64', params={}, constant=-1), FieldConfig(name='patienthealthsystemstayid', type='int64', params={}), FieldConfig(name='patientunitstayid', type='int64', params={}), ConstantFieldConfig(name='day', type='int64', params={}, constant=1), FieldConfig(name='hospitaladmitoffset', type='int64', params={}), FieldConfig(name='hospitaladmittime24', type='string', params={}), FieldConfig(name='hospitaldischargeyear', type='int64', params={}), ConstantFieldConfig(name='month', type='int64', params={}, constant=1)], pre_callbacks=[], callbacks=[CallbackConfig(callback='to_datetime', params={'year': 'hospitaldischargeyear', 'month': 'month', 'day': 'day', 'time': 'hospitaladmittime24', 'offset': 'hospitaladmitoffset', 'output': 'admission_timestamp'}, call=<open_icu.transform.callbacks.time.ToDatetime object at 0x763332a87250>)], post_callbacks=[], both_on=['patientunitstayid'], left_on=[], right_on=[], how='left', dtypes={'hadm_id': Int64, 'patienthealthsystemstayid': Int64, 'patientunitstayid': Int64, 'day': Int64, 'hospitaladmitoffset': Int64, 'hospitaladmittime24': String, 'hospitaldischargeyear': Int64, 'month': Int64}, join_params={'on': ['patientunitstayid']})], events=[EventConfig(name='drugamount', fields=MEDSEventFieldConfig(subject_id='patienthealthsystemstayid', time='event_timestamp', code=['src_table_code', 'drugname'], numeric_value='drugamount', text_value=None, extension={'hadm_id': 'hadm_id', 'stay_id': 'patientunitstayid', 'src_db_id': 'src_db_id'}), callbacks=[])], dtypes={'src_table_code': String, 'patientunitstayid': Int64, 'src_db_id': String, 'infusionoffset': Int64, 'drugamount': Float32, 'drugname': String}), TableConfig(name='vitalPeriodic', path='vitalPeriodic.csv', type=<TableType.CSV: 'csv'>, fields=[ConstantFieldConfig(name='src_table_code', type='string', params={}, constant='vitalPeriodic'), ConstantFieldConfig(name='heartrate_code', type='string', params={}, constant='HEART_RATE'), FieldConfig(name='patientunitstayid', type='int64', params={}), ConstantFieldConfig(name='src_db_id', type='string', params={}, constant='eicu'), FieldConfig(name='observationoffset', type='int64', params={}), FieldConfig(name='heartrate', type='float32', params={}), ConstantFieldConfig(name='heartrate_uom', type='string', params={}, constant='BPM')], pre_callbacks=[], callbacks=[], post_callbacks=[CallbackConfig(callback='add_offset', params={'datetime': 'admission_timestamp', 'offset': 'observationoffset', 'output': 'event_timestamp'}, call=<open_icu.transform.callbacks.time.AddOffset object at 0x763332a87250>)], join=[JsonTableConfig(name='patient', path='patient.csv', type=<TableType.CSV: 'csv'>, fields=[ConstantFieldConfig(name='hadm_id', type='int64', params={}, constant=-1), FieldConfig(name='patienthealthsystemstayid', type='int64', params={}), FieldConfig(name='patientunitstayid', type='int64', params={}), ConstantFieldConfig(name='day', type='int64', params={}, constant=1), FieldConfig(name='hospitaladmitoffset', type='int64', params={}), FieldConfig(name='hospi ...
